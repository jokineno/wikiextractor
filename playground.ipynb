# %%
from wikiextractor.extract import dropNested

# %%
text = "Chastre ( Moikka ) on kunta Belgiassa, Vallonian Brabantin provinssissa. Pinta-alaa Chastrella on 31,27 neliökilometriä. 1. tammikuuta 2007 kunnassa oli 6 819 asukasta, joista miehiä oli 48,97 % ja naisia 51,03 %. Asukastiheys oli 218 as./km². Kunnan pormestarina toimii Claude Jossart. Kanadalainen pianisti ja säveltäjä Séverin Moisse syntyi Chastressa tai läheisessä Walhain-Saint-Paulissa vuonna 1895."
dropNested(text, r"\(", r"\)")
# Out:
# 'Chastre  on kunta Belgiassa, Vallonian Brabantin provinssissa. Pinta-alaa Chastrella on 31,27 neliökilometriä. 1. tammikuuta 2007 kunnassa oli 6 819 asukasta, joista miehiä oli 48,97 % ja naisia 51,03 %. Asukastiheys oli 218 as./km². Kunnan pormestarina toimii Claude Jossart. Kanadalainen pianisti ja säveltäjä Séverin Moisse syntyi Chastressa tai läheisessä Walhain-Saint-Paulissa vuonna 1895.'

# %%
import json 
with open("metadata.json", "r") as f:
    data = json.load(f)

# %%
data.get()
# Out:
# {'abstract': 'Rheinau voi tarkoittaa ainakin seuraavia paikkoja:', 'title': 'Rheinau', 'paper_id': '549384'}
# {'abstract': 'Hämyvälskäri ("Ctenochaetus tominiensis") on kala.', 'title': 'Hämyvälskäri', 'paper_id': '523058'}
# {'abstract': 'Elämysyhteiskunta voi viitata seuraaviin asioihin:', 'title': 'Elämysyhteiskunta', 'paper_id': '570299'}
# {'abstract': 'The Newz on Nazarethin studioalbumi vuodelta 2008.', 'title': 'The Newz', 'paper_id': '527841'}
# {'abstract': 'Pins and Needles voi tarkoittaa seuraavia asioita:', 'title': 'Pins and Needles', 'paper_id': '532816'}
# {'abstract': 'Georgi Markov voi tarkoittaa seuraavia henkilöitä:', 'title': 'Georgi Markov', 'paper_id': '561182'}
# {'abstract': 'Christie’s on brittiläinen taidehuutokauppakamari.', 'title': 'Christie’s', 'paper_id': '589934'}
# {'abstract': 'Chris Sanders voi tarkoittaa seuraavia henkilöitä:', 'title': 'Chris Sanders', 'paper_id': '588772'}
# ...
